# %%
from static import *

# %%
im4 = M2.file(examples_dir / "IMG_0004.HEIC", cache_dir / "m2_out4.npy")

# %%
import matplotlib.pyplot as plt

# %%
im4.draw_candidates(plt.subplots()[1])
# Out:
# <Axes: >
